# %%
# from PIL import Image
# import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# %%
IMAGE_DATA_PATH = os.path.join("..", "Data")

# %%
train_gen = ImageDataGenerator(
    rescale = 1./255,
    validation_split = 0.2
)
train_gen

# %%
train_data = train_gen.flow_from_directory(
    IMAGE_DATA_PATH,
    target_size = (224,224),
    batch_size = 32,
    class_mode = "categorical",
    subset = "training"
)
# Out:
# Found 971 images belonging to 4 classes.

# %%
val_data = train_gen.flow_from_directory(
    IMAGE_DATA_PATH,
    target_size = (224,224),
    batch_size = 32,
    class_mode = "categorical",
    subset = "validation"
)
# Out:
# Found 241 images belonging to 4 classes.

# %%
model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape = (224,224,3)),
    layers.MaxPooling2D(),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),

    layers.Dense(
        train_data.num_classes,
        activation='softmax'
    )
])
# Out:
# c:\Users\win\OneDrive\Desktop\NN Soil Project\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.6210 - loss: 1.1862 - val_accuracy: 0.7842 - val_loss: 0.7265
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.8249 - loss: 0.5261 - val_accuracy: 0.7220 - val_loss: 0.6486
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8774 - loss: 0.3699 - val_accuracy: 0.8382 - val_loss: 0.4983
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9176 - loss: 0.2272 - val_accuracy: 0.8382 - val_loss: 0.3873
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9382 - loss: 0.1813 - val_accuracy: 0.8008 - val_loss: 0.4504
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9578 - loss: 0.1505 - val_accuracy: 0.7884 - val_loss: 0.5173
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.9681 - loss: 0.1146 - val_accuracy: 0.8133 - val_loss: 0.7154
# Epoch 8/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - accuracy: 0.9578 - loss: 0.1287 - val_accuracy: 0.8216 - val_loss: 1.0007
# Epoch 9/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9578 - loss: 0.1376 - val_accuracy: 0.7801 - val_loss: 0.7092
# Epoch 10/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.9753 - loss: 0.0827 - val_accuracy: 0.7884 - val_loss: 0.6410

# %%
model.save('SoilModel.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
